# %%
pip install vaderSentiment
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# Requirement already satisfied: vaderSentiment in /opt/conda/lib/python3.10/site-packages (3.3.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from vaderSentiment) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->vaderSentiment) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->vaderSentiment) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->vaderSentiment) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->vaderSentiment) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import re
import zipfile

# Directory paths for tweets and prices
train_tweet_dir = '/kaggle/input/multimodalai-prediction/public_dataset/train/tweets'
price_data_dir = '/kaggle/input/multimodalai-prediction/public_dataset/train/price_data'
output_price_data_dir = '/kaggle/working/price_data'  # Create a directory in the working space

# Create the output directory if it doesn't exist
os.makedirs(output_price_data_dir, exist_ok=True)

# Initialize VADER sentiment analyzer
analyzer = SentimentIntensityAnalyzer()

# Function to clean the tweet
def clean_tweet(tweet):
    tweet = re.sub(r"http\S+", "", tweet)  # Remove URLs
    tweet = re.sub(r"@\w+", "", tweet)     # Remove mentions
    tweet = re.sub(r"#\w+", "", tweet)     # Remove hashtags
    tweet = re.sub(r"[^\w\s]", "", tweet)  # Remove punctuation
    tweet = tweet.lower()                  # Convert to lowercase
    return tweet

# Function to get sentiment score using VADER
def get_sentiment_vader(tweet):
    sentiment = analyzer.polarity_scores(tweet)
    return sentiment['compound']

# Process tweets and price data
def process_coin_data(coin_name):
    # Load tweet data for the coin
    coin_tweet_folder = os.path.join(train_tweet_dir, coin_name)
    tweet_files = os.listdir(coin_tweet_folder)

    all_tweets = []
    for tweet_file in tweet_files:
        file_path = os.path.join(coin_tweet_folder, tweet_file)
        
        try:
            # Extract the date from the filename (assuming the filename contains the date)
            tweet_date = pd.to_datetime(tweet_file.replace('.csv', ''), format='%Y-%m-%d').date()

            # Load the tweets for that day
            tweet_data = pd.read_csv(file_path, engine='python', on_bad_lines='skip')
        except Exception as e:
            print(f"Error reading {file_path}: {e}")
            continue

        if 'tweet' in tweet_data.columns:
            # Clean the tweet text and get sentiment score
            tweet_data['cleaned_tweet'] = tweet_data['tweet'].apply(lambda x: clean_tweet(x) if pd.notnull(x) else '')
            tweet_data['sentiment_score'] = tweet_data['cleaned_tweet'].apply(lambda x: get_sentiment_vader(x) if x != '' else 0)
            
            # Add the date from the filename to the tweet data
            tweet_data['date'] = tweet_date  
            all_tweets.append(tweet_data[['date', 'sentiment_score']])

    if all_tweets:
        # Combine all tweets into a single DataFrame
        all_tweets_df = pd.concat(all_tweets)
        
        # Group by date and calculate the average sentiment score for each day
        daily_sentiment = all_tweets_df.groupby('date')['sentiment_score'].mean().reset_index()

        # Debugging: print daily sentiment data
        print(f"\nSentiment data for {coin_name}:")
        print(daily_sentiment.head(), len(daily_sentiment))  # Show the number of rows
    else:
        print(f"No sentiment data available for {coin_name}")
        daily_sentiment = pd.DataFrame(columns=['date', 'sentiment_score'])

    # Process price data
    price_file_path = os.path.join(price_data_dir, f"{coin_name}.csv")
    try:
        price_data = pd.read_csv(price_file_path)

        # Ensure datetime column is in proper format
        price_data['datetime'] = pd.to_datetime(price_data['datetime'])
        price_data['date'] = price_data['datetime'].dt.date  # Extract date from datetime

        # Debugging: print price data before merging
        print(f"\nPrice data for {coin_name} before merging:")
        print(price_data[['datetime', 'date']].head())

        # Merge sentiment with price data on date
        price_data = pd.merge(price_data, daily_sentiment, on='date', how='left')

        # Debugging: print price data after merging
        print(f"\nPrice data for {coin_name} after merging:")
        print(price_data[['datetime', 'date', 'sentiment_score']].head())

        # Handle NaN values in sentiment_score by filling with 0
        price_data['sentiment_score'] = price_data['sentiment_score'].fillna(0)

        # Optionally, drop the 'date' column if not needed anymore
        price_data.drop(columns='date', inplace=True)

        # Save the updated price data with sentiment scores to the output directory
        output_file_path = os.path.join(output_price_data_dir, f"{coin_name}.csv")
        price_data.to_csv(output_file_path, index=False)

    except Exception as e:
        print(f"Error processing price data for {coin_name}: {e}")

# Process and update sentiment for all coins
for coin_name in os.listdir(train_tweet_dir):
    print(f"Processing data for {coin_name}")
    process_coin_data(coin_name)

print("Sentiment scores added to price data.")

# Create a zip file of all updated CSVs
zip_file_path = '/kaggle/working/price_data.zip'
with zipfile.ZipFile(zip_file_path, 'w') as zipf:
    for root, dirs, files in os.walk(output_price_data_dir):
        for file in files:
            if file.endswith('.csv'):
                zipf.write(os.path.join(root, file), file)  # Write only the file name to zip

print(f"All updated price data files have been zipped into {zip_file_path}.")
# Out:
# Processing data for DIA
#
# Sentiment data for DIA:
#          date  sentiment_score
# 0  2020-08-18         0.187630
# 1  2020-08-19         0.181689
# 2  2020-08-20         0.149146
# 3  2020-08-21         0.163856
# 4  2020-08-22         0.178643 163
#
# Price data for DIA before merging:
#     datetime        date
# 0 2020-08-18  2020-08-18
# 1 2020-08-19  2020-08-19
# 2 2020-08-20  2020-08-20
# 3 2020-08-21  2020-08-21
# 4 2020-08-22  2020-08-22
#
# Price data for DIA after merging:
#     datetime        date  sentiment_score
# 0 2020-08-18  2020-08-18         0.187630
# 1 2020-08-19  2020-08-19         0.181689
# 2 2020-08-20  2020-08-20         0.149146
# 3 2020-08-21  2020-08-21         0.163856
# 4 2020-08-22  2020-08-22         0.178643
# Processing data for XSR
#
# Sentiment data for XSR:
#          date  sentiment_score
# 0  2020-08-06         0.384975
# 1  2020-08-07         0.204829
# 2  2020-08-08         0.050150
# 3  2020-08-09         0.123733
# 4  2020-08-10         0.000000 44
#
# Price data for XSR before merging:
#     datetime        date
# 0 2020-08-06  2020-08-06
# 1 2020-08-07  2020-08-07
# 2 2020-08-08  2020-08-08
# 3 2020-08-09  2020-08-09
# 4 2020-08-10  2020-08-10
#
# Price data for XSR after merging:
#     datetime        date  sentiment_score
# 0 2020-08-06  2020-08-06         0.384975
# 1 2020-08-07  2020-08-07         0.204829
# 2 2020-08-08  2020-08-08         0.050150
# 3 2020-08-09  2020-08-09         0.123733
# 4 2020-08-10  2020-08-10         0.000000
# Processing data for FUEL
#
# Sentiment data for FUEL:
#          date  sentiment_score
# 0  2019-04-05         0.348631
# 1  2019-04-06         0.406050
# 2  2019-04-07         0.473108
# 3  2019-04-08         0.258724
# 4  2019-04-09         0.315757 362
#
# Price data for FUEL before merging:
#     datetime        date
# 0 2018-01-17  2018-01-17
# 1 2018-01-18  2018-01-18
# 2 2018-01-19  2018-01-19
# 3 2018-01-20  2018-01-20
# 4 2018-01-21  2018-01-21
#
# Price data for FUEL after merging:
#     datetime        date  sentiment_score
# 0 2018-01-17  2018-01-17              NaN
# 1 2018-01-18  2018-01-18              NaN
# 2 2018-01-19  2018-01-19              NaN
# 3 2018-01-20  2018-01-20              NaN
# 4 2018-01-21  2018-01-21              NaN
# Processing data for BNT
#
# Sentiment data for BNT:
#          date  sentiment_score
# 0  2019-03-27         0.392384
# 1  2019-03-28         0.472067
# 2  2019-03-29         0.357566
# 3  2019-03-30         0.376790
# 4  2019-03-31         0.312182 190
#
# Price data for BNT before merging:
#     datetime        date
# 0 2018-01-08  2018-01-08
# 1 2018-01-09  2018-01-09
# 2 2018-01-10  2018-01-10
# 3 2018-01-11  2018-01-11
# 4 2018-01-12  2018-01-12
#
# Price data for BNT after merging:
#     datetime        date  sentiment_score
# 0 2018-01-08  2018-01-08              NaN
# 1 2018-01-09  2018-01-09              NaN
# 2 2018-01-10  2018-01-10              NaN
# 3 2018-01-11  2018-01-11              NaN
# 4 2018-01-12  2018-01-12              NaN
# Processing data for YEE
#
# Sentiment data for YEE:
#          date  sentiment_score
# 0  2018-09-25         0.000000
# 1  2018-10-01         0.127267
# 2  2018-10-02         0.170000
# 3  2018-10-05         0.000000
# 4  2018-10-09         0.624900 124
#
# Price data for YEE before merging:
#     datetime        date
# 0 2018-01-30  2018-01-30
# 1 2018-01-31  2018-01-31
# 2 2018-02-01  2018-02-01
# 3 2018-02-02  2018-02-02
# 4 2018-02-03  2018-02-03
#
# Price data for YEE after merging:
#     datetime        date  sentiment_score
# 0 2018-01-30  2018-01-30              NaN
# 1 2018-01-31  2018-01-31              NaN
# 2 2018-02-01  2018-02-01              NaN
# 3 2018-02-02  2018-02-02              NaN
# 4 2018-02-03  2018-02-03              NaN
# Processing data for RSR
#
# Sentiment data for RSR:
#          date  sentiment_score
# 0  2019-06-03         0.063433
# 1  2019-06-04         0.136902
# 2  2019-06-05         0.222878
# 3  2019-06-06         0.191004
# 4  2019-06-07         0.098788 389
#
# Price data for RSR before merging:
#     datetime        date
# 0 2019-06-03  2019-06-03
# 1 2019-06-04  2019-06-04
# 2 2019-06-05  2019-06-05
# 3 2019-06-06  2019-06-06
# 4 2019-06-07  2019-06-07
#
# Price data for RSR after merging:
#     datetime        date  sentiment_score
# 0 2019-06-03  2019-06-03         0.063433
# 1 2019-06-04  2019-06-04         0.136902
# 2 2019-06-05  2019-06-05         0.222878
# 3 2019-06-06  2019-06-06         0.191004
# 4 2019-06-07  2019-06-07         0.098788
# Processing data for OCEAN
#
# Sentiment data for OCEAN:
#          date  sentiment_score
# 0  2020-07-08         0.256895
# 1  2020-07-09         0.189840
# 2  2020-07-10         0.192110
# 3  2020-07-11         0.139988
# 4  2020-07-12         0.204971 155
#
# Price data for OCEAN before merging:
#     datetime        date
# 0 2020-07-08  2020-07-08
# 1 2020-07-09  2020-07-09
# 2 2020-07-10  2020-07-10
# 3 2020-07-11  2020-07-11
# 4 2020-07-12  2020-07-12
#
# Price data for OCEAN after merging:
#     datetime        date  sentiment_score
# 0 2020-07-08  2020-07-08         0.256895
# 1 2020-07-09  2020-07-09         0.189840
# 2 2020-07-10  2020-07-10         0.192110
# 3 2020-07-11  2020-07-11         0.139988
# 4 2020-07-12  2020-07-12         0.204971
# Processing data for GBP
#
# Sentiment data for GBP:
#          date  sentiment_score
# 0  2020-03-20         0.020976
# 1  2020-03-21         0.125797
# 2  2020-03-22         0.098312
# 3  2020-03-23         0.054417
# 4  2020-03-24         0.038954 90
#
# Price data for GBP before merging:
#     datetime        date
# 0 2020-03-20  2020-03-20
# 1 2020-03-21  2020-03-21
# 2 2020-03-22  2020-03-22
# 3 2020-03-23  2020-03-23
# 4 2020-03-24  2020-03-24
#
# Price data for GBP after merging:
#     datetime        date  sentiment_score
# 0 2020-03-20  2020-03-20         0.020976
# 1 2020-03-21  2020-03-21         0.125797
# 2 2020-03-22  2020-03-22         0.098312
# 3 2020-03-23  2020-03-23         0.054417
# 4 2020-03-24  2020-03-24         0.038954
# Processing data for TNT
#
# Sentiment data for TNT:
#          date  sentiment_score
# 0  2020-08-16         0.168040
# 1  2020-08-17         0.177108
# 2  2020-08-18         0.465350
# 3  2020-08-19         0.225500
# 4  2020-08-20         0.023550 124
#
# Price data for TNT before merging:
#     datetime        date
# 0 2017-11-24  2017-11-24
# 1 2017-11-25  2017-11-25
# 2 2017-11-26  2017-11-26
# 3 2017-11-27  2017-11-27
# 4 2017-11-28  2017-11-28
#
# Price data for TNT after merging:
#     datetime        date  sentiment_score
# 0 2017-11-24  2017-11-24              NaN
# 1 2017-11-25  2017-11-25              NaN
# 2 2017-11-26  2017-11-26              NaN
# 3 2017-11-27  2017-11-27              NaN
# 4 2017-11-28  2017-11-28              NaN
# Processing data for DAI
#
# Sentiment data for DAI:
#          date  sentiment_score
# 0  2020-05-21         0.177253
# 1  2020-05-22         0.128567
# 2  2020-05-23         0.154800
# 3  2020-05-24         0.169491
# 4  2020-05-25         0.087850 142
#
# Price data for DAI before merging:
#     datetime        date
# 0 2019-09-25  2019-09-25
# 1 2019-09-26  2019-09-26
# 2 2019-09-27  2019-09-27
# 3 2019-09-28  2019-09-28
# 4 2019-09-29  2019-09-29
#
# Price data for DAI after merging:
#     datetime        date  sentiment_score
# 0 2019-09-25  2019-09-25              NaN
# 1 2019-09-26  2019-09-26              NaN
# 2 2019-09-27  2019-09-27              NaN
# 3 2019-09-28  2019-09-28              NaN
# 4 2019-09-29  2019-09-29              NaN
# Processing data for CELR
#
# Sentiment data for CELR:
#          date  sentiment_score
# 0  2019-03-26         0.027459
# 1  2019-03-27         0.105446
# 2  2019-03-28         0.141226
# 3  2019-03-29         0.151292
# 4  2019-03-30         0.072115 378
#
# Price data for CELR before merging:
#     datetime        date
# 0 2019-03-26  2019-03-26
# 1 2019-03-27  2019-03-27
# 2 2019-03-28  2019-03-28
# 3 2019-03-29  2019-03-29
# 4 2019-03-30  2019-03-30
#
# Price data for CELR after merging:
#     datetime        date  sentiment_score
# 0 2019-03-26  2019-03-26         0.027459
# 1 2019-03-27  2019-03-27         0.105446
# 2 2019-03-28  2019-03-28         0.141226
# 3 2019-03-29  2019-03-29         0.151292
# 4 2019-03-30  2019-03-30         0.072115
# Processing data for AGI
#
# Sentiment data for AGI:
#          date  sentiment_score
# 0  2018-12-28         0.668506
# 1  2018-12-29         0.369952
# 2  2018-12-30         0.425548
# 3  2018-12-31         0.458529
# 4  2019-01-01         0.565664 447
#
# Price data for AGI before merging:
#     datetime        date
# 0 2018-05-09  2018-05-09
# 1 2018-05-10  2018-05-10
# 2 2018-05-11  2018-05-11
# 3 2018-05-12  2018-05-12
# 4 2018-05-13  2018-05-13
#
# Price data for AGI after merging:
#     datetime        date  sentiment_score
# 0 2018-05-09  2018-05-09              NaN
# 1 2018-05-10  2018-05-10              NaN
# 2 2018-05-11  2018-05-11              NaN
# 3 2018-05-12  2018-05-12              NaN
# 4 2018-05-13  2018-05-13              NaN
# Processing data for BZRX
#
# Sentiment data for BZRX:
#          date  sentiment_score
# 0  2020-08-31         0.217593
# 1  2020-09-01         0.177752
# 2  2020-09-02         0.142264
# 3  2020-09-03         0.146546
# 4  2020-09-04         0.150139 111
#
# Price data for BZRX before merging:
#     datetime        date
# 0 2020-08-31  2020-08-31
# 1 2020-09-01  2020-09-01
# 2 2020-09-02  2020-09-02
# 3 2020-09-03  2020-09-03
# 4 2020-09-04  2020-09-04
#
# Price data for BZRX after merging:
#     datetime        date  sentiment_score
# 0 2020-08-31  2020-08-31         0.217593
# 1 2020-09-01  2020-09-01         0.177752
# 2 2020-09-02  2020-09-02         0.142264
# 3 2020-09-03  2020-09-03         0.146546
# 4 2020-09-04  2020-09-04         0.150139
# Processing data for CKB
# No sentiment data available for CKB
#
# Price data for CKB before merging:
#     datetime        date
# 0 2019-11-20  2019-11-20
# 1 2019-11-21  2019-11-21
# 2 2019-11-22  2019-11-22
# 3 2019-11-23  2019-11-23
# 4 2019-11-24  2019-11-24
#
# Price data for CKB after merging:
#     datetime        date sentiment_score
# 0 2019-11-20  2019-11-20             NaN
# 1 2019-11-21  2019-11-21             NaN
# 2 2019-11-22  2019-11-22             NaN
# 3 2019-11-23  2019-11-23             NaN
# 4 2019-11-24  2019-11-24             NaN
# Processing data for ZEN
# /tmp/ipykernel_50/3243165881.py:96: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   price_data['sentiment_score'] = price_data['sentiment_score'].fillna(0)
# Sentiment data for ZEN:
#          date  sentiment_score
# 0  2019-02-19         0.179544
# 1  2019-02-20         0.206643
# 2  2019-02-21         0.143484
# 3  2019-02-22         0.289035
# 4  2019-02-23         0.208258 373
#
# Price data for ZEN before merging:
#     datetime        date
# 0 2018-02-12  2018-02-12
# 1 2018-02-13  2018-02-13
# 2 2018-02-14  2018-02-14
# 3 2018-02-15  2018-02-15
# 4 2018-02-16  2018-02-16
#
# Price data for ZEN after merging:
#     datetime        date  sentiment_score
# 0 2018-02-12  2018-02-12              NaN
# 1 2018-02-13  2018-02-13              NaN
# 2 2018-02-14  2018-02-14              NaN
# 3 2018-02-15  2018-02-15              NaN
# 4 2018-02-16  2018-02-16              NaN
# Processing data for DOTUP
#
# Sentiment data for DOTUP:
#          date  sentiment_score
# 0  2020-09-11         0.291337
# 1  2020-09-12         0.317445
# 2  2020-09-13         0.292403
# 3  2020-09-14         0.333211
# 4  2020-09-15         0.318200 94
#
# Price data for DOTUP before merging:
#     datetime        date
# 0 2020-09-11  2020-09-11
# 1 2020-09-12  2020-09-12
# 2 2020-09-13  2020-09-13
# 3 2020-09-14  2020-09-14
# 4 2020-09-15  2020-09-15
#
# Price data for DOTUP after merging:
#     datetime        date  sentiment_score
# 0 2020-09-11  2020-09-11         0.291337
# 1 2020-09-12  2020-09-12         0.317445
# 2 2020-09-13  2020-09-13         0.292403
# 3 2020-09-14  2020-09-14         0.333211
# 4 2020-09-15  2020-09-15         0.318200
# Processing data for CHAT
#
# Sentiment data for CHAT:
#          date  sentiment_score
# 0  2019-09-25          0.00000
# 1  2019-10-01          0.58590
# 2  2019-10-12          0.54990
# 3  2019-10-29          0.31245
# 4  2019-10-30          0.27320 65
#
# Price data for CHAT before merging:
#     datetime        date
# 0 2018-02-12  2018-02-12
# 1 2018-02-13  2018-02-13
# 2 2018-02-14  2018-02-14
# 3 2018-02-15  2018-02-15
# 4 2018-02-16  2018-02-16
#
# Price data for CHAT after merging:
#     datetime        date  sentiment_score
# 0 2018-02-12  2018-02-12              NaN
# 1 2018-02-13  2018-02-13              NaN
# 2 2018-02-14  2018-02-14              NaN
# 3 2018-02-15  2018-02-15              NaN
# 4 2018-02-16  2018-02-16              NaN
# Processing data for UTK
#
# Sentiment data for UTK:
#          date  sentiment_score
# 0  2020-07-22         0.000000
# 1  2020-07-23         0.294919
# 2  2020-07-24         0.150420
# 3  2020-07-25         0.228062
# 4  2020-07-26         0.175961 72
#
# Price data for UTK before merging:
#     datetime        date
# 0 2018-02-12  2018-02-12
# 1 2018-02-13  2018-02-13
# 2 2018-02-14  2018-02-14
# 3 2018-02-15  2018-02-15
# 4 2018-02-16  2018-02-16
#
# Price data for UTK after merging:
#     datetime        date  sentiment_score
# 0 2018-02-12  2018-02-12              NaN
# 1 2018-02-13  2018-02-13              NaN
# 2 2018-02-14  2018-02-14              NaN
# 3 2018-02-15  2018-02-15              NaN
# 4 2018-02-16  2018-02-16              NaN
# Processing data for SWAP
#
# Sentiment data for SWAP:
#          date  sentiment_score
# 0  2020-08-17         0.125435
# 1  2020-08-18         0.191295
# 2  2020-08-19         0.251013
# 3  2020-08-20         0.244251
# 4  2020-08-21         0.106211 151
#
# Price data for SWAP before merging:
#     datetime        date
# 0 2020-08-17  2020-08-17
# 1 2020-08-18  2020-08-18
# 2 2020-08-19  2020-08-19
# 3 2020-08-20  2020-08-20
# 4 2020-08-21  2020-08-21
#
# Price data for SWAP after merging:
#     datetime        date  sentiment_score
# 0 2020-08-17  2020-08-17         0.125435
# 1 2020-08-18  2020-08-18         0.191295
# 2 2020-08-19  2020-08-19         0.251013
# 3 2020-08-20  2020-08-20         0.244251
# 4 2020-08-21  2020-08-21         0.106211
# Processing data for CGLD
#
# Sentiment data for CGLD:
#          date  sentiment_score
# 0  2020-09-02         0.119203
# 1  2020-09-03         0.265120
# 2  2020-09-04         0.104417
# 3  2020-09-05         0.043520
# 4  2020-09-06         0.391629 85
#
# Price data for CGLD before merging:
#     datetime        date
# 0 2020-09-02  2020-09-02
# 1 2020-09-03  2020-09-03
# 2 2020-09-04  2020-09-04
# 3 2020-09-05  2020-09-05
# 4 2020-09-06  2020-09-06
#
# Price data for CGLD after merging:
#     datetime        date  sentiment_score
# 0 2020-09-02  2020-09-02         0.119203
# 1 2020-09-03  2020-09-03         0.265120
# 2 2020-09-04  2020-09-04         0.104417
# 3 2020-09-05  2020-09-05         0.043520
# 4 2020-09-06  2020-09-06         0.391629
# Processing data for ENJ
#
# Sentiment data for ENJ:
#          date  sentiment_score
# 0  2019-04-26         0.361910
# 1  2019-04-27         0.383597
# 2  2019-04-28         0.272891
# 3  2019-04-29         0.255304
# 4  2019-04-30         0.402826 374
#
# Price data for ENJ before merging:
#     datetime        date
# 0 2019-04-26  2019-04-26
# 1 2019-04-27  2019-04-27
# 2 2019-04-28  2019-04-28
# 3 2019-04-29  2019-04-29
# 4 2019-04-30  2019-04-30
#
# Price data for ENJ after merging:
#     datetime        date  sentiment_score
# 0 2019-04-26  2019-04-26         0.361910
# 1 2019-04-27  2019-04-27         0.383597
# 2 2019-04-28  2019-04-28         0.272891
# 3 2019-04-29  2019-04-29         0.255304
# 4 2019-04-30  2019-04-30         0.402826
# Processing data for SFG
#
# Sentiment data for SFG:
#          date  sentiment_score
# 0  2020-09-27         0.306594
# 1  2020-09-28         0.386500
# 2  2020-09-29         0.158500
# 3  2020-09-30         0.000000
# 4  2020-10-03         0.101150 46
#
# Price data for SFG before merging:
#     datetime        date
# 0 2020-09-27  2020-09-27
# 1 2020-09-28  2020-09-28
# 2 2020-09-29  2020-09-29
# 3 2020-09-30  2020-09-30
# 4 2020-10-01  2020-10-01
#
# Price data for SFG after merging:
#     datetime        date  sentiment_score
# 0 2020-09-27  2020-09-27         0.306594
# 1 2020-09-28  2020-09-28         0.386500
# 2 2020-09-29  2020-09-29         0.158500
# 3 2020-09-30  2020-09-30         0.000000
# 4 2020-10-01  2020-10-01              NaN
# Processing data for WXT
#
# Sentiment data for WXT:
#          date  sentiment_score
# 0  2019-07-03         0.122096
# 1  2019-07-04         0.260300
# 2  2019-07-05         0.236971
# 3  2019-07-06         0.188200
# 4  2019-07-07        -0.065200 205
#
# Price data for WXT before merging:
#     datetime        date
# 0 2019-07-03  2019-07-03
# 1 2019-07-04  2019-07-04
# 2 2019-07-05  2019-07-05
# 3 2019-07-06  2019-07-06
# 4 2019-07-07  2019-07-07
#
# Price data for WXT after merging:
#     datetime        date  sentiment_score
# 0 2019-07-03  2019-07-03         0.122096
# 1 2019-07-04  2019-07-04         0.260300
# 2 2019-07-05  2019-07-05         0.236971
# 3 2019-07-06  2019-07-06         0.188200
# 4 2019-07-07  2019-07-07        -0.065200
# Processing data for CHR
#
# Sentiment data for CHR:
#          date  sentiment_score
# 0  2020-05-07         0.275180
# 1  2020-05-08         0.263663
# 2  2020-05-09         0.157041
# 3  2020-05-10         0.236257
# 4  2020-05-11         0.173861 204
#
# Price data for CHR before merging:
#     datetime        date
# 0 2020-05-07  2020-05-07
# 1 2020-05-08  2020-05-08
# 2 2020-05-09  2020-05-09
# 3 2020-05-10  2020-05-10
# 4 2020-05-11  2020-05-11
#
# Price data for CHR after merging:
#     datetime        date  sentiment_score
# 0 2020-05-07  2020-05-07         0.275180
# 1 2020-05-08  2020-05-08         0.263663
# 2 2020-05-09  2020-05-09         0.157041
# 3 2020-05-10  2020-05-10         0.236257
# 4 2020-05-11  2020-05-11         0.173861
# Processing data for NEST
#
# Sentiment data for NEST:
#          date  sentiment_score
# 0  2020-08-07         0.225495
# 1  2020-08-08         0.245533
# 2  2020-08-09         0.190264
# 3  2020-08-10         0.187485
# 4  2020-08-11         0.109390 106
#
# Price data for NEST before merging:
#     datetime        date
# 0 2020-08-07  2020-08-07
# 1 2020-08-08  2020-08-08
# 2 2020-08-09  2020-08-09
# 3 2020-08-10  2020-08-10
# 4 2020-08-11  2020-08-11
#
# Price data for NEST after merging:
#     datetime        date  sentiment_score
# 0 2020-08-07  2020-08-07         0.225495
# 1 2020-08-08  2020-08-08         0.245533
# 2 2020-08-09  2020-08-09         0.190264
# 3 2020-08-10  2020-08-10         0.187485
# 4 2020-08-11  2020-08-11         0.109390
# Processing data for ONL
#
# Sentiment data for ONL:
#          date  sentiment_score
# 0  2019-04-27           0.0000
# 1  2019-05-18          -0.1591
# 2  2019-05-27           0.2837
# 3  2019-05-30          -0.1622
# 4  2019-06-11           0.0000 30
#
# Price data for ONL before merging:
#     datetime        date
# 0 2019-04-23  2019-04-23
# 1 2019-04-24  2019-04-24
# 2 2019-04-25  2019-04-25
# 3 2019-04-26  2019-04-26
# 4 2019-04-27  2019-04-27
#
# Price data for ONL after merging:
#     datetime        date  sentiment_score
# 0 2019-04-23  2019-04-23              NaN
# 1 2019-04-24  2019-04-24              NaN
# 2 2019-04-25  2019-04-25              NaN
# 3 2019-04-26  2019-04-26              NaN
# 4 2019-04-27  2019-04-27              0.0
# Processing data for DX
#
# Sentiment data for DX:
#          date  sentiment_score
# 0  2019-06-07        -0.570730
# 1  2019-06-08        -0.649050
# 2  2019-06-09        -0.641220
# 3  2019-06-10        -0.718925
# 4  2019-06-11        -0.459300 283
#
# Price data for DX before merging:
#     datetime        date
# 0 2019-06-07  2019-06-07
# 1 2019-06-08  2019-06-08
# 2 2019-06-09  2019-06-09
# 3 2019-06-10  2019-06-10
# 4 2019-06-11  2019-06-11
#
# Price data for DX after merging:
#     datetime        date  sentiment_score
# 0 2019-06-07  2019-06-07        -0.570730
# 1 2019-06-08  2019-06-08        -0.649050
# 2 2019-06-09  2019-06-09        -0.641220
# 3 2019-06-10  2019-06-10        -0.718925
# 4 2019-06-11  2019-06-11        -0.459300
# Processing data for AUC
#
# Sentiment data for AUC:
#          date  sentiment_score
# 0  2018-09-02         0.257477
# 1  2018-09-03         0.201812
# 2  2018-09-04         0.198115
# 3  2018-09-05         0.254371
# 4  2018-09-06         0.289300 418
#
# Price data for AUC before merging:
#     datetime        date
# 0 2018-09-02  2018-09-02
# 1 2018-09-03  2018-09-03
# 2 2018-09-04  2018-09-04
# 3 2018-09-05  2018-09-05
# 4 2018-09-06  2018-09-06
#
# Price data for AUC after merging:
#     datetime        date  sentiment_score
# 0 2018-09-02  2018-09-02         0.257477
# 1 2018-09-03  2018-09-03         0.201812
# 2 2018-09-04  2018-09-04         0.198115
# 3 2018-09-05  2018-09-05         0.254371
# 4 2018-09-06  2018-09-06         0.289300
# Processing data for DMG
#
# Sentiment data for DMG:
#          date  sentiment_score
# 0  2020-07-17         0.168958
# 1  2020-07-18         0.147011
# 2  2020-07-19         0.132619
# 3  2020-07-20         0.123904
# 4  2020-07-21         0.135156 122
#
# Price data for DMG before merging:
#     datetime        date
# 0 2020-07-17  2020-07-17
# 1 2020-07-18  2020-07-18
# 2 2020-07-19  2020-07-19
# 3 2020-07-20  2020-07-20
# 4 2020-07-21  2020-07-21
#
# Price data for DMG after merging:
#     datetime        date  sentiment_score
# 0 2020-07-17  2020-07-17         0.168958
# 1 2020-07-18  2020-07-18         0.147011
# 2 2020-07-19  2020-07-19         0.132619
# 3 2020-07-20  2020-07-20         0.123904
# 4 2020-07-21  2020-07-21         0.135156
# Processing data for QUN
#
# Sentiment data for QUN:
#          date  sentiment_score
# 0  2019-04-25           0.7003
# 1  2019-04-27           0.0000
# 2  2019-05-05           0.7717
# 3  2019-05-07           0.4404
# 4  2019-05-09           0.0000 58
#
# Price data for QUN before merging:
#     datetime        date
# 0 2018-02-12  2018-02-12
# 1 2018-02-13  2018-02-13
# 2 2018-02-14  2018-02-14
# 3 2018-02-15  2018-02-15
# 4 2018-02-16  2018-02-16
#
# Price data for QUN after merging:
#     datetime        date  sentiment_score
# 0 2018-02-12  2018-02-12              NaN
# 1 2018-02-13  2018-02-13              NaN
# 2 2018-02-14  2018-02-14              NaN
# 3 2018-02-15  2018-02-15              NaN
# 4 2018-02-16  2018-02-16              NaN
# Processing data for TFUEL
#
# Sentiment data for TFUEL:
#          date  sentiment_score
# 0  2019-03-27         0.205621
# 1  2019-03-28         0.101150
# 2  2019-03-29         0.139786
# 3  2019-03-30         0.067433
# 4  2019-03-31         0.014820 350
#
# Price data for TFUEL before merging:
#     datetime        date
# 0 2019-03-27  2019-03-27
# 1 2019-03-28  2019-03-28
# 2 2019-03-29  2019-03-29
# 3 2019-03-30  2019-03-30
# 4 2019-03-31  2019-03-31
#
# Price data for TFUEL after merging:
#     datetime        date  sentiment_score
# 0 2019-03-27  2019-03-27         0.205621
# 1 2019-03-28  2019-03-28         0.101150
# 2 2019-03-29  2019-03-29         0.139786
# 3 2019-03-30  2019-03-30         0.067433
# 4 2019-03-31  2019-03-31         0.014820
# Processing data for HSC
#
# Sentiment data for HSC:
#          date  sentiment_score
# 0  2018-07-16         0.177900
# 1  2018-07-17         0.000000
# 2  2018-07-18         0.170000
# 3  2018-07-19        -0.003171
# 4  2018-07-20         0.000000 477
#
# Price data for HSC before merging:
#     datetime        date
# 0 2018-07-16  2018-07-16
# 1 2018-07-17  2018-07-17
# 2 2018-07-18  2018-07-18
# 3 2018-07-19  2018-07-19
# 4 2018-07-20  2018-07-20
#
# Price data for HSC after merging:
#     datetime        date  sentiment_score
# 0 2018-07-16  2018-07-16         0.177900
# 1 2018-07-17  2018-07-17         0.000000
# 2 2018-07-18  2018-07-18         0.170000
# 3 2018-07-19  2018-07-19        -0.003171
# 4 2018-07-20  2018-07-20         0.000000
# Processing data for MBL
#
# Sentiment data for MBL:
#          date  sentiment_score
# 0  2019-06-26          0.01290
# 1  2019-06-27          0.24122
# 2  2019-06-29          0.51060
# 3  2019-06-30          0.51060
# 4  2019-07-01          0.51060 288
#
# Price data for MBL before merging:
#     datetime        date
# 0 2019-06-25  2019-06-25
# 1 2019-06-26  2019-06-26
# 2 2019-06-27  2019-06-27
# 3 2019-06-28  2019-06-28
# 4 2019-06-29  2019-06-29
#
# Price data for MBL after merging:
#     datetime        date  sentiment_score
# 0 2019-06-25  2019-06-25              NaN
# 1 2019-06-26  2019-06-26          0.01290
# 2 2019-06-27  2019-06-27          0.24122
# 3 2019-06-28  2019-06-28              NaN
# 4 2019-06-29  2019-06-29          0.51060
# Processing data for LEND
#
# Sentiment data for LEND:
#          date  sentiment_score
# 0  2019-03-19         0.277222
# 1  2019-03-20         0.287932
# 2  2019-03-21         0.323816
# 3  2019-03-22         0.225908
# 4  2019-03-23         0.410986 346
#
# Price data for LEND before merging:
#     datetime        date
# 0 2018-01-17  2018-01-17
# 1 2018-01-18  2018-01-18
# 2 2018-01-19  2018-01-19
# 3 2018-01-20  2018-01-20
# 4 2018-01-21  2018-01-21
#
# Price data for LEND after merging:
#     datetime        date  sentiment_score
# 0 2018-01-17  2018-01-17              NaN
# 1 2018-01-18  2018-01-18              NaN
# 2 2018-01-19  2018-01-19              NaN
# 3 2018-01-20  2018-01-20              NaN
# 4 2018-01-21  2018-01-21              NaN
# Processing data for KIN
#
# Sentiment data for KIN:
#          date  sentiment_score
# 0  2020-08-06         0.167840
# 1  2020-08-07         0.253683
# 2  2020-08-08         0.222711
# 3  2020-08-09         0.139379
# 4  2020-08-10         0.153707 157
#
# Price data for KIN before merging:
#     datetime        date
# 0 2020-08-06  2020-08-06
# 1 2020-08-07  2020-08-07
# 2 2020-08-08  2020-08-08
# 3 2020-08-09  2020-08-09
# 4 2020-08-10  2020-08-10
#
# Price data for KIN after merging:
#     datetime        date  sentiment_score
# 0 2020-08-06  2020-08-06         0.167840
# 1 2020-08-07  2020-08-07         0.253683
# 2 2020-08-08  2020-08-08         0.222711
# 3 2020-08-09  2020-08-09         0.139379
# 4 2020-08-10  2020-08-10         0.153707
# Processing data for KMD
#
# Sentiment data for KMD:
#          date  sentiment_score
# 0  2020-08-11         0.137811
# 1  2020-08-12         0.220202
# 2  2020-08-13         0.176087
# 3  2020-08-14         0.157454
# 4  2020-08-15         0.159712 134
#
# Price data for KMD before merging:
#     datetime        date
# 0 2020-08-11  2020-08-11
# 1 2020-08-12  2020-08-12
# 2 2020-08-13  2020-08-13
# 3 2020-08-14  2020-08-14
# 4 2020-08-15  2020-08-15
#
# Price data for KMD after merging:
#     datetime        date  sentiment_score
# 0 2020-08-11  2020-08-11         0.137811
# 1 2020-08-12  2020-08-12         0.220202
# 2 2020-08-13  2020-08-13         0.176087
# 3 2020-08-14  2020-08-14         0.157454
# 4 2020-08-15  2020-08-15         0.159712
# Processing data for YFII
#
# Sentiment data for YFII:
#          date  sentiment_score
# 0  2020-08-28         0.240860
# 1  2020-08-29         0.108817
# 2  2020-08-30         0.104530
# 3  2020-08-31         0.145831
# 4  2020-09-01         0.117076 163
#
# Price data for YFII before merging:
#     datetime        date
# 0 2020-08-28  2020-08-28
# 1 2020-08-29  2020-08-29
# 2 2020-08-30  2020-08-30
# 3 2020-08-31  2020-08-31
# 4 2020-09-01  2020-09-01
#
# Price data for YFII after merging:
#     datetime        date  sentiment_score
# 0 2020-08-28  2020-08-28         0.240860
# 1 2020-08-29  2020-08-29         0.108817
# 2 2020-08-30  2020-08-30         0.104530
# 3 2020-08-31  2020-08-31         0.145831
# 4 2020-09-01  2020-09-01         0.117076
# Processing data for BCN
#
# Sentiment data for BCN:
#          date  sentiment_score
# 0  2019-01-07        -0.027839
# 1  2019-01-08         0.133248
# 2  2019-01-09         0.057682
# 3  2019-01-10         0.125252
# 4  2019-01-11         0.165465 513
#
# Price data for BCN before merging:
#     datetime        date
# 0 2019-01-07  2019-01-07
# 1 2019-01-08  2019-01-08
# 2 2019-01-09  2019-01-09
# 3 2019-01-10  2019-01-10
# 4 2019-01-11  2019-01-11
#
# Price data for BCN after merging:
#     datetime        date  sentiment_score
# 0 2019-01-07  2019-01-07        -0.027839
# 1 2019-01-08  2019-01-08         0.133248
# 2 2019-01-09  2019-01-09         0.057682
# 3 2019-01-10  2019-01-10         0.125252
# 4 2019-01-11  2019-01-11         0.165465
# Processing data for ETP
#
# Sentiment data for ETP:
#          date  sentiment_score
# 0  2019-02-01        -0.296000
# 1  2019-02-02        -0.075876
# 2  2019-02-03         0.071840
# 3  2019-02-04         0.024735
# 4  2019-02-05         0.028422 447
#
# Price data for ETP before merging:
#     datetime        date
# 0 2017-09-20  2017-09-20
# 1 2017-09-21  2017-09-21
# 2 2017-09-22  2017-09-22
# 3 2017-09-23  2017-09-23
# 4 2017-09-24  2017-09-24
#
# Price data for ETP after merging:
#     datetime        date  sentiment_score
# 0 2017-09-20  2017-09-20              NaN
# 1 2017-09-21  2017-09-21              NaN
# 2 2017-09-22  2017-09-22              NaN
# 3 2017-09-23  2017-09-23              NaN
# 4 2017-09-24  2017-09-24              NaN
# Sentiment scores added to price data.
# All updated price data files have been zipped into /kaggle/working/price_data.zip.
